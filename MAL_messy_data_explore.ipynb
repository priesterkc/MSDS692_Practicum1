# %%
import pandas as pd
from ast import literal_eval
import numpy as np

# %%
filepath = "MAL_anime_dataset/MAL_anime.csv"
anime_df = pd.read_csv(filepath)

anime_df.head()
# Out:
#       id                             title  num_scoring_users  \
# 0   5114  Fullmetal Alchemist: Brotherhood            1846307
# 1  11061            Hunter x Hunter (2011)            1488156
# 2   9253                       Steins;Gate            1240087
# 3     21                         One Piece            1076776
# 4   1535                        Death Note            2426765
#
#              status media_type  num_episodes           start_date  \
# 0   finished_airing         tv            64  2009-04-05 00:00:00
# 1   finished_airing         tv           148  2011-10-02 00:00:00
# 2   finished_airing         tv            24  2011-04-06 00:00:00
# 3  currently_airing         tv             0  1999-10-20 00:00:00
# 4   finished_airing         tv            37  2006-10-04 00:00:00
#
#               end_date  mean        source  ...                      studios  \
# 0  2010-07-04 00:00:00  9.14         manga  ...                    ['Bones']
# ...

# %%
anime_df.columns
# Out:
# Index(['id', 'title', 'num_scoring_users', 'status', 'media_type',
#        'num_episodes', 'start_date', 'end_date', 'mean', 'source',
#        'num_list_users', 'popularity', 'num_favorites', 'rank',
#        'average_episode_duration', 'rating', 'start_season_year',
#        'start_season_season', 'broadcast_day_of_the_week',
#        'broadcast_start_time', 'genres', 'studios', 'synopsis', 'nsfw',
#        'created_at', 'updated_at', 'main_picture_medium', 'main_picture_large',
#        'alternative_titles_en', 'alternative_titles_ja',
#        'alternative_titles_synonyms'],
#       dtype='object')

# %%
anime_df['media_type'].unique()
# Out:
# array(['tv', 'movie', 'ova', 'ona', 'music', 'special', 'unknown'],
#       dtype=object)

# %%
anime_df['source'].unique()
# Out:
# array(['manga', 'visual_novel', 'original', 'light_novel', 'web_manga',
#        'novel', '4_koma_manga', 'game', 'other', 'web_novel',
#        'mixed_media', 'music', 'card_game', 'book', nan, 'picture_book',
#        'radio'], dtype=object)

# %%
anime_df[['title', 'alternative_titles_en','num_scoring_users', 'num_list_users']].head(20)
# Out:
#                                  title  \
# 0     Fullmetal Alchemist: Brotherhood
# 1               Hunter x Hunter (2011)
# 2                          Steins;Gate
# 3                            One Piece
# 4                           Death Note
# 5                   Shingeki no Kyojin
# 6      Code Geass: Hangyaku no Lelouch
# 7                   Naruto: Shippuuden
# 8              Neon Genesis Evangelion
# 9                       Kimi no Na wa.
# 10                    Kimetsu no Yaiba
# 11             Shigatsu wa Kimi no Uso
# 12                      Koe no Katachi
# 13          Tengen Toppa Gurren Lagann
# 14                        Cowboy Bebop
# 15  Code Geass: Hangyaku no Lelouch R2
# 16                 Jujutsu Kaisen (TV)
# 17                              Naruto
# 18                           Haikyuu!!
# 19                Clannad: After Story
#
#                       alternative_titles_en  num_scoring_users  num_list_users
# ...

# %%
anime_df[['title', 'alternative_titles_en','num_scoring_users', 'num_list_users']].tail(20)
# Out:
#                                                    title  \
# 23992                  Zhi Duoduo Qihuan Xingkong Zhi Lu
# 23993                                        Melody Line
# 23994                                      Iroha Matsuri
# 23995   Electric Magic feat. Kagamine Len & Kagamine Rin
# 23996  Yume no Mayu ～ Genki Ippai Otōto to Asa Kara B...
# 23997                                         Yi Zhi Xie
# 23998                              Jia Ru Wo Shi Wu Song
# 23999                         Penguin Minna Kyoudai 2020
# 24000                Jushen Zhan Ji Dui: Guidao Xianfeng
# 24001                Bai Bian Ji Shou: Luo Luo Lixian Ji
# 24002               Ke Yao Shanlin Zhi Fengshou De Jijie
# 24003     Xing Mao Wenhua Da Jiangtang Zhi Mingzhu Gushi
# 24004                              Luo Baobei 3rd Season
# 24005           Tian Tian Quan Baobei Zhi Feixing Leyuan
# 24006                                  Mini Tegong Dui X
# ...

# %%
anime_df[['title','rank','mean', 'popularity', 'num_list_users',]].head(10)
# Out:
#                               title  rank  mean  popularity  num_list_users
# 0  Fullmetal Alchemist: Brotherhood     1  9.14           3         2897486
# 1            Hunter x Hunter (2011)     6  9.05          10         2387337
# 2                       Steins;Gate     3  9.08          13         2248209
# 3                         One Piece    65  8.65          26         1893379
# 4                        Death Note    74  8.62           2         3421349
# 5                Shingeki no Kyojin   102  8.53           1         3438932
# 6   Code Geass: Hangyaku no Lelouch    49  8.70          17         1995638
# 7                Naruto: Shippuuden   285  8.24          16         2126396
# 8           Neon Genesis Evangelion   206  8.34          48         1559217
# 9                    Kimi no Na wa.    24  8.87          11         2367090

# %%
anime_df[['title', 'genres']].explode('genres').head(20)
# Out:
#                                  title  \
# 0     Fullmetal Alchemist: Brotherhood
# 1               Hunter x Hunter (2011)
# 2                          Steins;Gate
# 3                            One Piece
# 4                           Death Note
# 5                   Shingeki no Kyojin
# 6      Code Geass: Hangyaku no Lelouch
# 7                   Naruto: Shippuuden
# 8              Neon Genesis Evangelion
# 9                       Kimi no Na wa.
# 10                    Kimetsu no Yaiba
# 11             Shigatsu wa Kimi no Uso
# 12                      Koe no Katachi
# 13          Tengen Toppa Gurren Lagann
# 14                        Cowboy Bebop
# 15  Code Geass: Hangyaku no Lelouch R2
# 16                 Jujutsu Kaisen (TV)
# 17                              Naruto
# 18                           Haikyuu!!
# 19                Clannad: After Story
#
#                                                genres
# 0   ['Action', 'Adventure', 'Drama', 'Fantasy', 'M...
# ...

# %%
anime_df.dtypes
# Out:
# id                               int64
# title                           object
# num_scoring_users                int64
# status                          object
# media_type                      object
# num_episodes                     int64
# start_date                      object
# end_date                        object
# mean                           float64
# source                          object
# num_list_users                   int64
# popularity                       int64
# num_favorites                    int64
# rank                             int64
# average_episode_duration        object
# rating                          object
# start_season_year                int64
# start_season_season             object
# broadcast_day_of_the_week       object
# broadcast_start_time            object
# genres                          object
# studios                         object
# synopsis                        object
# nsfw                            object
# ...

# %%
type(anime_df['genres'][0])
# Out:
# str

# %%
anime_df['genres'] = anime_df['genres'].apply(literal_eval)

# %%
type(anime_df['genres'][0])
# Out:
# list

# %%
anime_df[['title', 'genres']].explode('genres').head(20)
# Out:
#                               title         genres
# 0  Fullmetal Alchemist: Brotherhood         Action
# 0  Fullmetal Alchemist: Brotherhood      Adventure
# 0  Fullmetal Alchemist: Brotherhood          Drama
# 0  Fullmetal Alchemist: Brotherhood        Fantasy
# 0  Fullmetal Alchemist: Brotherhood       Military
# 0  Fullmetal Alchemist: Brotherhood        Shounen
# 1            Hunter x Hunter (2011)         Action
# 1            Hunter x Hunter (2011)      Adventure
# 1            Hunter x Hunter (2011)        Fantasy
# 1            Hunter x Hunter (2011)        Shounen
# 2                       Steins;Gate          Drama
# 2                       Steins;Gate  Psychological
# 2                       Steins;Gate         Sci-Fi
# 2                       Steins;Gate       Suspense
# 2                       Steins;Gate    Time Travel
# 3                         One Piece         Action
# 3                         One Piece      Adventure
# ...

# %%
type(anime_df['studios'][0])
# Out:
# str

# %%
anime_df['studios'] = anime_df['studios'].apply(literal_eval)
type(anime_df['studios'][0])
# Out:
# list

# %%
anime_df['alternative_titles_synonyms'].head(20)
# Out:
# 0     ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                        ['HxH (2011)']
# 2                                                    []
# 3                                                ['OP']
# 4                                                ['DN']
# 5                                        ['AoT', 'SnK']
# 6                                                    []
# 7                       ['Naruto Hurricane Chronicles']
# 8                              ['Shinseiki Evangelion']
# 9                                                    []
# 10                       ['Blade of Demon Destruction']
# 11                                          ['Kimiuso']
# 12                               ['The Shape of Voice']
# 13    ['Tengen Toppa Gurren-Lagann', 'Making Break-T...
# 14                                                   []
# 15    ['Code Geass: Hangyaku no Lelouch 2nd Season',...
# 16                             ['Sorcery Fight', 'JJK']
# ...

# %%
anime_df['nsfw'].unique()
# Out:
# array(['white', 'gray'], dtype=object)

# %%
anime_df['rating'].unique()
# Out:
# array(['r', 'pg_13', 'r+', 'pg', 'g', nan, 'rx'], dtype=object)

# %%
anime_df[['alternative_titles_en', 'popularity','num_list_users', 'num_favorites']].head(10)
# Out:
#                   alternative_titles_en  popularity  num_list_users  \
# 0      Fullmetal Alchemist: Brotherhood           3         2897486
# 1                       Hunter x Hunter          10         2387337
# 2                           Steins;Gate          13         2248209
# 3                             One Piece          26         1893379
# 4                            Death Note           2         3421349
# 5                       Attack on Titan           1         3438932
# 6  Code Geass: Lelouch of the Rebellion          17         1995638
# 7                      Naruto Shippuden          16         2126396
# 8               Neon Genesis Evangelion          48         1559217
# 9                            Your Name.          11         2367090
#
#    num_favorites
# 0         202552
# 1         182740
# 2         171579
# 3         167571
# 4         155891
# 5         152655
# 6          99388
# 7          97728
# 8          91211
# 9          81809

# %%
small_anime_df = anime_df[['id', 'title', 'alternative_titles_en', 'mean','num_scoring_users',
                           'popularity','num_list_users','rank','num_favorites',
                           'media_type','rating','studios', 'genres','source','num_episodes',
                           'average_episode_duration','start_date', 'end_date',
                           'start_season_year','start_season_season', 'broadcast_day_of_the_week',
                           'broadcast_start_time',]]

small_anime_df.head(10)
# Out:
#       id                             title  \
# 0   5114  Fullmetal Alchemist: Brotherhood
# 1  11061            Hunter x Hunter (2011)
# 2   9253                       Steins;Gate
# 3     21                         One Piece
# 4   1535                        Death Note
# 5  16498                Shingeki no Kyojin
# 6   1575   Code Geass: Hangyaku no Lelouch
# 7   1735                Naruto: Shippuuden
# 8     30           Neon Genesis Evangelion
# 9  32281                    Kimi no Na wa.
#
#                   alternative_titles_en  mean  num_scoring_users  popularity  \
# 0      Fullmetal Alchemist: Brotherhood  9.14            1846307           3
# 1                       Hunter x Hunter  9.05            1488156          10
# 2                           Steins;Gate  9.08            1240087          13
# 3                             One Piece  8.65            1076776          26
# 4                            Death Note  8.62            2426765           2
# ...

# %%
len(small_anime_df)
# Out:
# 24012

# %%
small_anime_df['new_title'] = small_anime_df['alternative_titles_en']

small_anime_df['new_title'].fillna(small_anime_df['title'], inplace=True)
# Out:
# C:\Users\kprie\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\kprie\Anaconda3\lib\site-packages\pandas\core\series.py:4523: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
small_anime_df[['title','alternative_titles_en']].tail(10)
# Out:
#                                                 title alternative_titles_en
# 24002            Ke Yao Shanlin Zhi Fengshou De Jijie                   NaN
# 24003  Xing Mao Wenhua Da Jiangtang Zhi Mingzhu Gushi                   NaN
# 24004                           Luo Baobei 3rd Season                   NaN
# 24005        Tian Tian Quan Baobei Zhi Feixing Leyuan                   NaN
# 24006                               Mini Tegong Dui X                   NaN
# 24007                                Xiao Feiji Ka Ka                   NaN
# 24008                                Sai Ya Lixian Ji                   NaN
# 24009                                    Xiling Diguo          Xyrin Empire
# 24010                                      Pochi Hana                   NaN
# 24011                                   Zhui Meng Zhe                   NaN

# %%
type(small_anime_df['alternative_titles_en'][50])
# Out:
# float

# %%
small_anime_df[small_anime_df['alternative_titles_en'].isnull()].head(10)
# Out:
#         id                   title alternative_titles_en  mean  \
# 50   37521            Vinland Saga                   NaN  8.73
# 80   50265            Spy x Family                   NaN  9.01
# 143  39533                   Given                   NaN  8.35
# 232  39195                Beastars                   NaN  7.88
# 241  40052         Great Pretender                   NaN  8.26
# 243  43299     Wonder Egg Priority                   NaN  7.72
# 255   8425                  Gosick                   NaN  8.06
# 264  33674   No Game No Life: Zero                   NaN  8.22
# 278  38668              Dorohedoro                   NaN  8.07
# 283  48561  Jujutsu Kaisen 0 Movie                   NaN  8.52
#
#      num_scoring_users  popularity  num_list_users  rank  num_favorites  \
# 50              602015          99         1105223    43          32867
# 80              257960         178          786158    11          24114
# ...

# %%
unpack_anime_df = small_anime_df.explode('genres')

unpack_anime_df.head(10)
# Out:
#       id                             title             alternative_titles_en  \
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
#
#    mean  num_scoring_users  popularity  num_list_users  rank  num_favorites  \
# ...

# %%
len(unpack_anime_df)
# Out:
# 63912

# %%
unpack_anime_df = unpack_anime_df.explode('studios')

unpack_anime_df.head(10)
# Out:
#       id                             title             alternative_titles_en  \
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 0   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist: Brotherhood
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
# 1  11061            Hunter x Hunter (2011)                   Hunter x Hunter
#
#    mean  num_scoring_users  popularity  num_list_users  rank  num_favorites  \
# ...

# %%
len(unpack_anime_df)
# Out:
# 67838

# %%
small_anime_df.loc[small_anime_df['media_type'] == 'unknown']
# Out:
#           id                                              title  \
# 2081   49363                       SK∞ (Shinsaku Anime Project)
# 2488   50803           Jaku-Chara Tomozaki-kun (Shinsaku Anime)
# 2618   51533                           Tonikaku Kawaii: Seifuku
# 2881   51440                  Sasaki to Miyano (Shinsaku Anime)
# 2985   49981  Kimi to Boku no Saigo no Senjou, Aruiwa Sekai ...
# ...      ...                                                ...
# 22064  50387          Ginga-dan PR Eizou: Sekai ni Heiwa wo-hen
# 22202  24023                                         Project758
# 22649  50912                                              INORI
# 23359  43760                                       Hikari no Ou
# 23893  50684                                           Rhapsody
#
#                            alternative_titles_en  mean  num_scoring_users  \
# 2081                                         NaN   0.0                  1
# ...

# %%
small_anime_df.loc[small_anime_df['media_type'] == 'ona']
# Out:
#           id                                              title  \
# 104    35120                                  Devilman: Crybaby
# 273    44074                                  Shiguang Dailiren
# 294    48661       JoJo no Kimyou na Bouken Part 6: Stone Ocean
# 309    37208                                      Mo Dao Zu Shi
# 385     5060                                Hetalia Axis Powers
# ...      ...                                                ...
# 23990  35071           Noah's Animal Clinic Medical Book Record
# 23992  38911                  Zhi Duoduo Qihuan Xingkong Zhi Lu
# 23996  42495  Yume no Mayu ～ Genki Ippai Otōto to Asa Kara B...
# 24009  50431                                       Xiling Diguo
# 24011  51967                                      Zhui Meng Zhe
#
#                                    alternative_titles_en  mean  \
# 104                                    Devilman: Crybaby  7.77
# 273                                           Link Click  8.79
# ...

# %%
small_anime_df.loc[small_anime_df['media_type'] == 'special']
# Out:
#           id                                              title  \
# 764    35466                               ReLIFE: Kanketsu-hen
# 1080   34103  Danganronpa 3: The End of Kibougamine Gakuen -...
# 1132   16001                       Kokoro Connect: Michi Random
# 1135    4059          Clannad: Mou Hitotsu no Sekai, Tomoyo-hen
# 1152    7338       Darker than Black: Kuro no Keiyakusha Gaiden
# ...      ...                                                ...
# 23910  28925                              Youkai Watch: Best 10
# 23912  29437            Detective Conan: Happy New Year Special
# 23970  48638  Hibike! Euphonium 5th Anniversary Disc Kiramek...
# 23985  25087                    Ie Naki Ko Remy Specials (2001)
# 23986  25599                            Vampiyan Kids Promotion
#
#                                    alternative_titles_en  mean  \
# 764                                    ReLIFE: Final Arc  8.21
# 1080   Danganronpa 3: The End of Hope's Peak High Sch...  7.45
# ...

# %%
unpack_anime_df.loc[unpack_anime_df['genres'].isnull()]
# Out:
#           id                    title alternative_titles_en  mean  \
# 1020   50549                   Bubble                Bubble  7.34
# 3931   51098        Shinobi no Ittoki                   NaN  0.00
# 4352   50709           Lycoris Recoil                   NaN  0.00
# 5416   33187         Katsudou Shashin                   NaN  5.47
# 6094   32468                  Nirvana                   NaN  6.79
# ...      ...                      ...                   ...   ...
# 23250  49901        Yummy Yummy Yummy     Yummy Yummy Yummy  0.00
# 23284  49902             Tsuki (2016)                   NaN  0.00
# 23336  49903             Game of Dice          GAME OF DICE  0.00
# 23349  38640                  Tug-Tug                   NaN  0.00
# 23428  51185  Nonsense Bungaku (2022)                   NaN  0.00
#
#        num_scoring_users  popularity  num_list_users   rank  num_favorites  \
# 1020               55662        1523          118900   2264            987
# ...

# %%
unpack_anime_df.loc[unpack_anime_df['genres'] == 'Idols (Male)']
# Out:
#           id                                              title  \
# 767    10321                Uta no☆Prince-sama♪ Maji Love 1000%
# 942    33899                                           IDOLiSH7
# 1409   32212                                    Ensemble Stars!
# 1431   12711                Uta no☆Prince-sama♪ Maji Love 2000%
# 1770   37962                             IDOLiSH7: Second Beat!
# ...      ...                                                ...
# 22450  39644                                       Setsugetsuka
# 22753  49122                                       Endless Vide
# 23224  41197                               Magical Love Potion!
# 23714  38648  King of Prism: Shiny Seven Stars IV - Louis x ...
# 23920  39677                                     Chuizhi Shijie
#
#        alternative_titles_en  mean  num_scoring_users  popularity  \
# 767       Uta no Prince Sama  7.04              92969        1038
# ...
